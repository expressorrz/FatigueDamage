# %%
import rasterio
import glob
import numpy as np
import os

tiff_path_0 = '../rawdataset/A014_0_52_22.tiff'
tiff_path_1 = '../rawdataset/A014_1_52_22.tiff'
with rasterio.open(tiff_path_0) as src0:
    src0 = src0.read()

with rasterio.open(tiff_path_1) as src1:
    src1 = src1.read()
# Out:
# /home/ruiruizhong/miniconda3/envs/pytorch/lib/python3.8/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
print(src0.shape, src1.shape)
# Out:
# (1, 2048, 1024) (1, 2048, 1024)

# %%
src0 = np.array(src0)[0]
src1 = np.array(src1)[0]
np.save('src0.npy', src0)
print(src0)
# Out:
# [[ 4  5  4 ... 10  9 10]
#  [ 5  5  4 ...  9 10  9]
#  [ 4  5  4 ...  9 11 10]
#  ...
#  [ 4  4  4 ...  5  5  5]
#  [ 4  4  3 ...  5  5  5]
#  [ 3  4  3 ...  5  5  5]]

# %%
# src0 = np.where(src0 > 50, 255, 0)
# src1 = np.where(src1 > 50, 255, 0)

# %%
import matplotlib.pyplot as plt
import cv2

# pic0 = src0[128:1920, 128:]
# pic1 = src1[128:1920, :896]
pic0 = src0
pic1 = src1
pic0 = cv2.resize(pic0, (512, 512))
pic1 = cv2.resize(pic1, (512, 512))
print(pic0.shape, pic1.shape)



fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(pic0, cmap='gray')
ax[0].set_title('Camera 0')
ax[1].imshow(pic1, cmap='gray')
ax[1].set_title('Camera 1')

plt.show()
# Out:
# (512, 512) (512, 512)
